# %% [markdown]
# # 🐼 Pandas - Class 6: GroupBy & Aggregations
# Welcome to **Class 6** of our Pandas series. Today we’ll learn how to group data and perform aggregations.

# %% [markdown]
# ## 1. Concept of Split–Apply–Combine
# - **Split** the data into groups based on some criteria.
# - **Apply** a function (e.g., sum, mean) to each group.
# - **Combine** the results into a new DataFrame or Series.
#
# This is the core idea behind `groupby`.

# %%
import pandas as pd

# New dataset: Employees, their Department, and Salary
data = {
    "Employee": ["John", "Sarah", "Mike", "Anna", "Tom", "Laura", "Steve", "Kate"],
    "Department": ["HR", "IT", "IT", "Finance", "Finance", "HR", "IT", "Finance"],
    "Salary": [50000, 70000, 72000, 65000, 60000, 52000, 75000, 58000]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#   Employee Department  Salary
# 0     John         HR   50000
# 1    Sarah         IT   70000
# 2     Mike         IT   72000
# 3     Anna    Finance   65000
# 4      Tom    Finance   60000
# 5    Laura         HR   52000
# 6    Steve         IT   75000
# 7     Kate    Finance   58000

# %%
df.groupby("Department")['Salary'].mean()
df.groupby("Department")['Salary'].Sum()
#average salary by department
#max salary by department
#min salary by department
df.groupby("Department")['Salary'].mean()
df.groupby("Department")['Salary'].max()
df.groupby("Department")['Salary'].min()
df.groupby("Department")['Employee'].count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3628/3354096492.py in <cell line: 0>()
#      12
#      13 df.groupby("Department")['Salary'].mean()
# ---> 14 df.groupby("Department")['Salary'].Sum()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#    1361             return self[attr]
#    1362
# -> 1363         raise AttributeError(
#    1364             f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'Sum'

# %%
#average salary by department
#max salary by department
#min salary by department
#mentos zindagi
df.groupby('Department')['Salary'].agg['mean' , 'max' , min]}

# %% [markdown]
# ## 2. Using `groupby()` with Aggregation Functions
# - Use `groupby('col').mean()` or other functions like sum, count, min, max.
# - You can also use `agg()` to pass multiple functions at once.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3628/156545592.py in <cell line: 0>()
#       1 df.groupby("Department")['Salary'].mean()
# ----> 2 df.groupby("Department")['Salary'].Sum()
#       3
#       4 df.groupby("Department")['Employee'].count()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#    1361             return self[attr]
#    1362
# -> 1363         raise AttributeError(
#    1364             f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'Sum'

# %% [markdown]
# ## 3. Multiple Aggregations on Different Columns
# - With `agg()`, you can specify different functions for each column.
# - Example: `df.groupby('Dept').agg({'Salary':'mean', 'Age':'max'})`.

# %%
import pandas as pd

# Same dataset
data = {
    "Employee": ["John", "Sarah", "Mike", "Anna", "Tom", "Laura", "Steve", "Kate"],
    "Department": ["HR", "IT", "IT", "Finance", "Finance", "HR", "IT", "Finance"],
    "Salary": [50000, 70000, 72000, 65000, 60000, 52000, 75000, 58000],
    "Age": [28, 32, 30, 27, 35, 29, 31, 26]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
#department wise (mean , max ,  min )salary and (mean , max )age
df.groupby('Department').agg({
    "Salary" : ['mean' , 'min' , 'max'],
    "Age" : ['mean' ,'max'],


})
# Out:
# Original DataFrame:
#   Employee Department  Salary  Age
# 0     John         HR   50000   28
# 1    Sarah         IT   70000   32
# 2     Mike         IT   72000   30
# 3     Anna    Finance   65000   27
# 4      Tom    Finance   60000   35
# 5    Laura         HR   52000   29
# 6    Steve         IT   75000   31
# 7     Kate    Finance   58000   26
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3628/2564992490.py in <cell line: 0>()
#      13 print(df)
#      14 #department wise (mean , max ,  min )salary and (mean , max )age
# ---> 15 df.groupby('Department').agg({
#      16     "Salary" : ['mean' , 'min' , 'max'],
#      17     "Age" : ['mean' 'max']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1430
#    1431         op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432         result = op.agg()
#    1433         if not is_dict_like(func) and result is not None:
#    1434             # GH #52849
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in agg(self)
#     188
#     189         if is_dict_like(func):
# --> 190             return self.agg_dict_like()
#     191         elif is_list_like(func):
#     192             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     421         Result of aggregation.
#     422         """
# --> 423         return self.agg_or_apply_dict_like(op_name="agg")
#     424
#     425     def compute_dict_like(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in agg_or_apply_dict_like(self, op_name)
#    1606             obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607         ):
# -> 1608             result_index, result_data = self.compute_dict_like(
#    1609                 op_name, selected_obj, selection, kwargs
#    1610             )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     495             # key used for column selection and output
#     496             results = [
# --> 497                 getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     498                 for key, how in func.items()
#     499             ]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     255             kwargs["engine"] = engine
#     256             kwargs["engine_kwargs"] = engine_kwargs
# --> 257             ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     258             if relabeling:
#     259                 # columns is not narrowed by mypy from relabeling flag
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     360             for idx, (name, func) in enumerate(arg):
#     361                 key = base.OutputKey(label=name, position=idx)
# --> 362                 results[key] = self.aggregate(func, *args, **kwargs)
#     363
#     364         if any(isinstance(x, DataFrame) for x in results.values()):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     247             if engine_kwargs is not None:
#     248                 kwargs["engine_kwargs"] = engine_kwargs
# --> 249             return getattr(self, func)(*args, **kwargs)
#     250
#     251         elif isinstance(func, abc.Iterable):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#    1361             return self[attr]
#    1362
# -> 1363         raise AttributeError(
#    1364             f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'meanmax'

# %% [markdown]
# ## 4. Pivot Tables & Crosstab
# - `pivot_table()` summarizes data like Excel pivot tables.
# - `crosstab()` shows frequency counts of combinations of factors.
# - Both are powerful for summarizing and comparing groups.

# %%
#values = output
#index = group by kisse krna he
#aggfunc = mean , max, min

#avrg salary by department
df.pivot_table(values = 'Salary', index = ' Department',aggfunc='mean')




#df["AgeGroup"] = pd.cut(df["Age"], bins=[25, 30, 35, 40], labels=["25-30", "31-35", "36-40"])
#EDA{exploratort data analysis}
print(df['Age'])
pd.cut(df['Age'] , bins = [25,30,35,40] , labels = ['25-30' , '31-35' , '36-40'])

#crosstab_result = pd.crosstab(df["Department"], df["AgeGroup"])
#df
pd.crosstab(df['Department'] , df['Age Group']) #isme har ek usme kitne a rhe he voh btayega
df.groupby("Department")['Age Group'].count() # isme total
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3628/501899933.py in <cell line: 0>()
#       3 #aggfunc = mean , max, min
#       4 #avrg salary by department
# ----> 5 df.pivot_table(values = 'Salary', index =  ' Department',aggfunc='mean')
#       6
#       7
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9507         from pandas.core.reshape.pivot import pivot_table
#    9508
# -> 9509         return pivot_table(
#    9510             self,
#    9511             values=values,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     100         return table.__finalize__(data, method="pivot_table")
#     101
# --> 102     table = __internal_pivot_table(
#     103         data,
#     104         values,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     170
#     171     observed_bool = False if observed is lib.no_default else observed
# --> 172     grouped = data.groupby(keys, observed=observed_bool, sort=sort, dropna=dropna)
#     173     if observed is lib.no_default and any(
#     174         ping._passed_categorical for ping in grouped._grouper.groupings
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: ' Department'

# %% [markdown]
# ## Mini Practice
# 1. Create a DataFrame with columns: Department, Employee, Salary, Age, City.
# 2. Group by Department to get average Salary and max Age.
# 3. Apply multiple aggregations using agg().
# 4. Create a pivot_table to see mean Salary by Department and City.
# 5. Build a crosstab for Department vs City.

# %%
# 1. Create a DataFrame with columns: Department, Employee, Salary, Age, City

# 2. Group by Department to get average Salary and max Age
# Write your code here

# 3. Apply multiple aggregations using agg()
# Example: mean Salary, max Age per Department
# Write your code here

# 4. Create a pivot_table to see mean Salary by Department and City
# Write your code here

# 5. Build a crosstab for Department vs City
# Write your code here

# %% [markdown]
# ---
# ## Summary
# - Learned the split–apply–combine concept.
# - Used `groupby()` with aggregation functions.
# - Applied multiple aggregations to different columns.
# - Explored `pivot_table` and `crosstab` for summarizing data.
