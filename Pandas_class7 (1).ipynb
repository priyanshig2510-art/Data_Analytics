# %% [markdown]
# # 🐼 Pandas - Class 7: Merging, Joining & Concatenation
# Welcome to **Class 7** of our Pandas series. Today we’ll learn how to combine multiple DataFrames using different techniques.

# %% [markdown]
# ## 1. Using `concat()` for Stacking Data
# - `pd.concat()` combines DataFrames vertically (rows) or horizontally (columns).
# - Use `axis=0` for vertical stacking (default), `axis=1` for horizontal.
# - `ignore_index=True` can reset the index after concatenation.

# %%
import pandas as pd
# Dataset 1: Product details
df1 = pd.DataFrame({"ProductID" : [101,102,103],
                  "Productname" : ['Pen ','Notebook','Marker'],
                   "Price":[10,50,30]
                    })
# Dataset 2: More products (same columns as df1 → good for vertical stacking)
df2 = pd.DataFrame({
    "ProductID" : [104,105],
    'ProductName' : ["Pencil",'Eraser'],
    "Price":[5,8]
})
# Dataset 3: Additional info (different columns → good for horizontal stacking)
df3 = pd.DataFrame({
    "Stock" : [100,60,80],
    "Rating" :[4.5,4.7,4.8]

})
print(df1)
print(df2)
print(df3)
#1. Vertical Stacking() > combine df1 df2 rows
#print(pd.concat([df1,df2], ignore_index=True))

#2. horizontal stacking (work on col df1 and df 3)
print(pd.concat([df1,df3],axis=1))
# Out:
#    ProductID Productname  Price
# 0        101        Pen      10
# 1        102    Notebook     50
# 2        103      Marker     30
#    ProductID ProductName  Price
# 0        104      Pencil      5
# 1        105      Eraser      8
#    Stock  Rating
# 0    100     4.5
# 1     60     4.7
# 2     80     4.8
#    ProductID Productname  Price  Stock  Rating
# 0        101        Pen      10    100     4.5
# 1        102    Notebook     50     60     4.7
# 2        103      Marker     30     80     4.8

# %% [markdown]
# ## 2. Using `merge()` for SQL-Style Joins
# - `merge()` is similar to SQL joins.
# - Specify `on` or `left_on`/`right_on` to choose key columns.
# - Join types: `inner` (default), `left`, `right`, `outer`.

# %%
#product = concating df1 and df2 on the basis of rows

products = pd.concat([df1,df2], ignore_index=True)

sales = pd.DataFrame({
    "ProductID" : [101,102,104,106],
    "UnitsSold" : [500,200,150,50]
})
print(products)
print(sales)

# inner join -> only matching ProductId
inner = pd.merge(products,sales, on='ProductID',how='inner')
print(inner)

#outer join
outer = pd.merge(products,sales,on='ProductID',how = 'outer')
print(outer)

#left join (left full common on right)
#right join (right full common on left)


left = pd.merge(products,sales,on='ProductID',how = 'left')
print(left)


right = pd.merge(products,sales,on='ProductID',how = 'right')
print(right)
# Out:
#    ProductID Productname  Price ProductName
# 0        101        Pen      10         NaN
# 1        102    Notebook     50         NaN
# 2        103      Marker     30         NaN
# 3        104         NaN      5      Pencil
# 4        105         NaN      8      Eraser
#    ProductID  UnitsSold
# 0        101        500
# 1        102        200
# 2        104        150
# 3        106         50
#    ProductID Productname  Price ProductName  UnitsSold
# 0        101        Pen      10         NaN        500
# 1        102    Notebook     50         NaN        200
# 2        104         NaN      5      Pencil        150
#    ProductID Productname  Price ProductName  UnitsSold
# 0        101        Pen    10.0         NaN      500.0
# 1        102    Notebook   50.0         NaN      200.0
# 2        103      Marker   30.0         NaN        NaN
# 3        104         NaN    5.0      Pencil      150.0
# 4        105         NaN    8.0      Eraser        NaN
# 5        106         NaN    NaN         NaN       50.0
#    ProductID Productname  Price ProductName  UnitsSold
# 0        101        Pen      10         NaN      500.0
# 1        102    Notebook     50         NaN      200.0
# 2        103      Marker     30         NaN        NaN
# 3        104         NaN      5      Pencil      150.0
# 4        105         NaN      8      Eraser        NaN
#    ProductID Productname  Price ProductName  UnitsSold
# 0        101        Pen    10.0         NaN        500
# 1        102    Notebook   50.0         NaN        200
# 2        104         NaN    5.0      Pencil        150
# 3        106         NaN    NaN         NaN         50

# %% [markdown]
# ## 3. Using `join()` with Index Alignment
# - `join()` joins DataFrames on their index or on a key column.
# - By default, joins on index; can specify `on='col'`.
# - Useful for adding columns to an existing DataFrame.

# %%
#join work on rows
print(products)

stock = pd.DataFrame({
    "Stock" : [100,60,80,120,150],

},index=[101,102,103,104,105])
print(stock)

#products = products.set_index('ProductID')
print(products)
#products.join(stock)

#we can still join two df instead of using set_index
#products.join(stock, on='ProductID')
# Out:
#           Productname  Price ProductName  Stock
# ProductID
# 101              Pen      10         NaN    100
# 102          Notebook     50         NaN     60
# 103            Marker     30         NaN     80
# 104               NaN      5      Pencil    120
# 105               NaN      8      Eraser    150
#      Stock
# 101    100
# 102     60
# 103     80
# 104    120
# 105    150
#           Productname  Price ProductName  Stock
# ProductID
# 101              Pen      10         NaN    100
# 102          Notebook     50         NaN     60
# 103            Marker     30         NaN     80
# 104               NaN      5      Pencil    120
# 105               NaN      8      Eraser    150
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1009/2374712585.py in <cell line: 0>()
#      13
#      14 #we can still join two df instead of using set_index
# ---> 15 products.join(stock, on='ProductID')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10755                     validate=validate,
#   10756                 )
# > 10757             return merge(
#   10758                 self,
#   10759                 other,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     182             validate=validate,
#     183         )
# --> 184         return op.get_result(copy=copy)
#     185
#     186
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in get_result(self, copy)
#     886         join_index, left_indexer, right_indexer = self._get_join_info()
#     887
# --> 888         result = self._reindex_and_concat(
#     889             join_index, left_indexer, right_indexer, copy=copy
#     890         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     838         right = self.right[:]
#     839
# --> 840         llabels, rlabels = _items_overlap_with_suffix(
#     841             self.left._info_axis, self.right._info_axis, self.suffixes
#     842         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2719
#    2720     if not lsuffix and not rsuffix:
# -> 2721         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2722
#    2723     def renamer(x, suffix: str | None):
#
# ValueError: columns overlap but no suffix specified: Index(['Stock'], dtype='object')

# %% [markdown]
# ## 4. Practical Examples
# - Combine sales and revenue data to see performance.
# - Merge students with marks to link records.
# - Practice with realistic datasets to understand alignment and missing data handling.

# %% [markdown]
# ## Mini Practice
# 1. Create three DataFrames: Products, Sales, and Revenue.
# 2. Concatenate them vertically and horizontally.
# 3. Merge Sales and Revenue using different join types.
# 4. Join Products with Sales based on index or a key.
# 5. Analyze missing values after joins.

# %%
# 1. Create three DataFrames: Products, Sales, and Revenue

# 2. Concatenate them vertically and horizontally
# Write your code here

# 3. Merge Sales and Revenue using different join types (inner, left, right, outer)
# Write your code here

# 4. Join Products with Sales based on index or a key
# Write your code here

# 5. Analyze missing values after joins
# Use isna(), info(), or describe() to explore gaps
# Write your code here

# %% [markdown]
# ---
# ## Summary
# - Used `concat()` for stacking data vertically and horizontally.
# - Performed SQL-style joins with `merge()`.
# - Applied `join()` with index alignment.
# - Explored practical use-cases like sales vs revenue, students vs marks.
